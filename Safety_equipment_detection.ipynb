# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthikhot/object_detection/blob/main/Safety_equipment_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.11.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (588.3 MB)
#      |████████████████████████████████| 588.3 MB 21 kB/s
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (1.51.1)
# Collecting keras<2.12,>=2.11.0
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 54.0 MB/s
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (1.14.1)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#      |████████████████████████████████| 439 kB 73.3 MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (1.21.6)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (14.0.6)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (57.4.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (0.28.0)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.12.6-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (2.1.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (4.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (3.19.6)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (1.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (1.15.0)
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 50.4 MB/s
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.38.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-gpu) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow-gpu) (3.0.9)
# Installing collected packages: tensorflow-estimator, tensorboard, keras, flatbuffers, tensorflow-gpu
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.2 requires flatbuffers<2,>=1.12, but you have flatbuffers 22.12.6 which is incompatible.
# tensorflow 2.9.2 requires keras<2.10.0,>=2.9.0rc0, but you have keras 2.11.0 which is incompatible.
# tensorflow 2.9.2 requires tensorboard<2.10,>=2.9, but you have tensorboard 2.11.0 which is incompatible.
# tensorflow 2.9.2 requires tensorflow-estimator<2.10.0,>=2.9.0rc0, but you have tensorflow-estimator 2.11.0 which is incompatible.
# Successfully installed flatbuffers-22.12.6 keras-2.11.0 tensorboard-2.11.0 tensorflow-estimator-2.11.0 tensorflow-gpu-2.11.0

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.11.0

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 79994, done.
# remote: Counting objects: 100% (170/170), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 79994 (delta 75), reused 157 (delta 69), pack-reused 79824
# Receiving objects: 100% (79994/79994), 594.22 MiB | 35.93 MiB/s, done.
# Resolving deltas: 100% (56935/56935), done.

# %%
pwd
# Out:
# '/content'

# %%
cd /content/models/research
# Out:
# /content/models/research

# %%
pwd
# Out:
# '/content/models/research'

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !git clone https://github.com/cocodataset/cocoapi.git
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 32.10 MiB/s, done.
# Resolving deltas: 100% (576/576), done.

# %%
cd cocoapi/PythonAPI
# Out:
# /content/models/research/cocoapi/PythonAPI

# %%
# !make
# Out:
# python setup.py build_ext --inplace
# running build_ext
# cythoning pycocotools/_mask.pyx to pycocotools/_mask.c
# /usr/local/lib/python3.8/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/models/research/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pycocotools._mask' extension
# creating build
# creating build/common
# creating build/temp.linux-x86_64-3.8
# creating build/temp.linux-x86_64-3.8/pycocotools
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.8/dist-packages/numpy/core/include -I../common -I/usr/include/python3.8 -c ../common/maskApi.c -o build/temp.linux-x86_64-3.8/../common/maskApi.o -Wno-cpp -Wno-unused-function -std=c99
# ../common/maskApi.c: In function ‘rleDecode’:
# ../common/maskApi.c:46:7: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#        for( k=0; k<R[i].cnts[j]; k++ ) *(M++)=v; v=!v; }}
#        ^~~
# ../common/maskApi.c:46:49: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#        for( k=0; k<R[i].cnts[j]; k++ ) *(M++)=v; v=!v; }}
#                                                  ^
# ../common/maskApi.c: In function ‘rleFrPoly’:
# ../common/maskApi.c:166:3: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#    for(j=0; j<k; j++) x[j]=(int)(scale*xy[j*2+0]+.5); x[k]=x[0];
#    ^~~
# ../common/maskApi.c:166:54: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#    for(j=0; j<k; j++) x[j]=(int)(scale*xy[j*2+0]+.5); x[k]=x[0];
#                                                       ^
# ../common/maskApi.c:167:3: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#    for(j=0; j<k; j++) y[j]=(int)(scale*xy[j*2+1]+.5); y[k]=y[0];
#    ^~~
# ../common/maskApi.c:167:54: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#    for(j=0; j<k; j++) y[j]=(int)(scale*xy[j*2+1]+.5); y[k]=y[0];
#                                                       ^
# ../common/maskApi.c: In function ‘rleToString’:
# ../common/maskApi.c:212:7: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#        if(more) c |= 0x20; c+=48; s[p++]=c;
#        ^~
# ../common/maskApi.c:212:27: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#        if(more) c |= 0x20; c+=48; s[p++]=c;
#                            ^
# ../common/maskApi.c: In function ‘rleFrString’:
# ../common/maskApi.c:220:3: warning: this ‘while’ clause does not guard... [-Wmisleading-indentation]
#    while( s[m] ) m++; cnts=malloc(sizeof(uint)*m); m=0;
#    ^~~~~
# ../common/maskApi.c:220:22: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘while’
#    while( s[m] ) m++; cnts=malloc(sizeof(uint)*m); m=0;
#                       ^~~~
# ../common/maskApi.c:228:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#      if(m>2) x+=(long) cnts[m-2]; cnts[m++]=(uint) x;
#      ^~
# ../common/maskApi.c:228:34: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#      if(m>2) x+=(long) cnts[m-2]; cnts[m++]=(uint) x;
#                                   ^~~~
# ../common/maskApi.c: In function ‘rleToBbox’:
# ../common/maskApi.c:141:31: warning: ‘xp’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#        if(j%2==0) xp=x; else if(xp<x) { ys=0; ye=h-1; }
#                                ^
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.8/dist-packages/numpy/core/include -I../common -I/usr/include/python3.8 -c pycocotools/_mask.c -o build/temp.linux-x86_64-3.8/pycocotools/_mask.o -Wno-cpp -Wno-unused-function -std=c99
# creating build/lib.linux-x86_64-3.8
# creating build/lib.linux-x86_64-3.8/pycocotools
# x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 -Wl,-Bsymbolic-functions -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.8/../common/maskApi.o build/temp.linux-x86_64-3.8/pycocotools/_mask.o -o build/lib.linux-x86_64-3.8/pycocotools/_mask.cpython-38-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-3.8/pycocotools/_mask.cpython-38-x86_64-linux-gnu.so -> pycocotools
# rm -rf build

# %%
cp -r pycocotools /content/models/research

# %%
pwd
# Out:
# '/content/models/research/cocoapi/PythonAPI'

# %%
cd ..
# Out:
# /content/models/research/cocoapi

# %%
cd ..
# Out:
# /content/models/research

# %%
cp object_detection/packages/tf2/setup.py .

# %%
# !python -m pip install --use-feature=2020-resolver .
# Out:
# WARNING: --use-feature=2020-resolver no longer has any effect, since it is now the default dependency resolver in pip. This will become an error in pip 21.0.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
# Collecting apache-beam
#   Downloading apache_beam-2.43.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.5 MB)
#      |████████████████████████████████| 14.5 MB 58 kB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (4.9.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (3.2.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (0.29.32)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (0.5.5)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 70.4 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (2.0.6)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (1.3.5)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.11.2-py2.py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 60.9 MB/s
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.29.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (26.9 MB)
#      |████████████████████████████████| 26.9 MB 1.3 MB/s
# Requirement already satisfied: keras in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (2.11.0)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 6.0 MB/s
# Collecting sacrebleu<=2.2.0
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      |████████████████████████████████| 116 kB 77.0 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2022.6.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.8/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.8.10)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.21.6)
# Collecting portalocker
#   Downloading portalocker-2.6.0-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting pyyaml<6.0,>=5.1
#   Downloading PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
#      |████████████████████████████████| 662 kB 79.1 MB/s
# Collecting tensorflow~=2.11.0
#   Downloading tensorflow-2.11.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (588.3 MB)
#      |████████████████████████████████| 588.3 MB 20 kB/s
# Collecting immutabledict
#   Downloading immutabledict-2.2.3-py3-none-any.whl (4.0 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.6.0.66)
# Collecting py-cpuinfo>=3.3.0
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.7.3-py2.py3-none-any.whl (238 kB)
#      |████████████████████████████████| 238 kB 67.9 MB/s
# Collecting tensorflow-text~=2.11.0
#   Downloading tensorflow_text-2.11.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 55.7 MB/s
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 57.1 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.4 MB/s
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.8)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 57.4 MB/s
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.6.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.12.11)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.15.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.0.4)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.17.4)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.15.0 in /usr/local/lib/python3.8/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.19.6)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.8/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.23.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.57.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.12.7)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.64.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.8/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (7.0.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->object-detection==0.1) (2022.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.4)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (22.12.6)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.28.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (14.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (57.4.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (2.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (4.4.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (21.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.51.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.38.4)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (3.11.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.7)
# Collecting requests<3.0.0dev,>=2.18.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.7 MB/s
# Collecting fasteners<1.0,>=0.3
#   Downloading fasteners-0.18-py3-none-any.whl (18 kB)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam->object-detection==0.1) (1.3.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.8/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 77.5 MB/s
# Collecting pymongo<4.0.0,>=3.8.0
#   Downloading pymongo-3.13.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (526 kB)
#      |████████████████████████████████| 526 kB 59.6 MB/s
# Collecting orjson<4.0
#   Downloading orjson-3.8.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
#      |████████████████████████████████| 278 kB 75.4 MB/s
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: pyarrow<10.0.0,>=0.15.1 in /usr/local/lib/python3.8/dist-packages (from apache-beam->object-detection==0.1) (9.0.0)
# Collecting zstandard<1,>=0.18.0
#   Downloading zstandard-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 58.8 MB/s
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.7.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 59.7 MB/s
# Collecting cloudpickle~=2.2.0
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Collecting objsize<0.6.0,>=0.5.2
#   Downloading objsize-0.5.2-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.8/dist-packages (from apache-beam->object-detection==0.1) (1.22.1)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.1.1)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.8/dist-packages (from lvis->object-detection==0.1) (4.6.0.66)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.8/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.8/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.7.1)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.9.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.12.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.10.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.29.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 47.4 MB/s
# Building wheels for collected packages: object-detection, dill, avro-python3, docopt, seqeval
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1696474 sha256=8168bbc8ef26a38da842e4a7efe30516ce3eec155a7ed7df9ca08a85f2cbab40
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ixxucy2n/wheels/7d/96/c1/072a751379735e8dfdada1def1c62a89afb3cc45654fd6fd28
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78544 sha256=3f5a19d2cff04b79247f1fc8d815948b95516d51e1245f480fe6249b604b0a2a
#   Stored in directory: /root/.cache/pip/wheels/07/35/78/e9004fa30578734db7f10e7a211605f3f0778d2bdde38a239d
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=44009 sha256=9bd88cfb543310eaef1c5f150602483553e7c5de1cea9aa4acba46fdf9fe62d2
#   Stored in directory: /root/.cache/pip/wheels/bb/73/e9/d273421f5723c4bf544dcf9eb097bda94421ef8d3252699f0a
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=4fdd4e0b996d9d25be71e7e7a3a5a98cf18a124f097be8ba57f80ce1eb17e2a2
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16179 sha256=5a6359e2afd6b7445b377a0f0494278783d6555363e7084554eb653051ad8266
#   Stored in directory: /root/.cache/pip/wheels/ad/5c/ba/05fa33fa5855777b7d686e843ec07452f22a66a138e290e732
# Successfully built object-detection dill avro-python3 docopt seqeval
# Installing collected packages: requests, pyparsing, tensorflow-io-gcs-filesystem, tensorflow, portalocker, docopt, dill, colorama, zstandard, tf-slim, tensorflow-text, tensorflow-model-optimization, tensorflow-addons, seqeval, sentencepiece, sacrebleu, pyyaml, pymongo, py-cpuinfo, orjson, objsize, immutabledict, hdfs, fasteners, fastavro, cloudpickle, tf-models-official, tensorflow-io, lvis, avro-python3, apache-beam, object-detection
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.28.0
#     Uninstalling tensorflow-io-gcs-filesystem-0.28.0:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.28.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.2
#     Uninstalling tensorflow-2.9.2:
#       Successfully uninstalled tensorflow-2.9.2
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
#     Uninstalling dill-0.3.6:
#       Successfully uninstalled dill-0.3.6
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.3.3
#     Uninstalling pymongo-4.3.3:
#       Successfully uninstalled pymongo-4.3.3
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.5.0
#     Uninstalling cloudpickle-1.5.0:
#       Successfully uninstalled cloudpickle-1.5.0
# Successfully installed apache-beam-2.43.0 avro-python3-1.10.2 cloudpickle-2.2.0 colorama-0.4.6 dill-0.3.1.1 docopt-0.6.2 fastavro-1.7.0 fasteners-0.18 hdfs-2.7.0 immutabledict-2.2.3 lvis-0.5.3 object-detection-0.1 objsize-0.5.2 orjson-3.8.3 portalocker-2.6.0 py-cpuinfo-9.0.0 pymongo-3.13.0 pyparsing-2.4.7 pyyaml-5.4.1 requests-2.28.1 sacrebleu-2.2.0 sentencepiece-0.1.97 seqeval-1.2.2 tensorflow-2.11.0 tensorflow-addons-0.19.0 tensorflow-io-0.29.0 tensorflow-io-gcs-filesystem-0.29.0 tensorflow-model-optimization-0.7.3 tensorflow-text-2.11.0 tf-models-official-2.11.2 tf-slim-1.1.0 zstandard-0.19.0

# %%
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# 2022-12-23 08:44:11.256227: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-23 08:44:11.256389: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-23 08:44:11.256408: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Running tests under Python 3.8.16: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-12-23 08:44:17.087998: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# W1223 08:44:17.351214 140694111016832 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.51s
# I1223 08:44:17.622522 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.51s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.67s
# I1223 08:44:18.293636 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.67s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.28s
# I1223 08:44:18.575682 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.28s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.27s
# I1223 08:44:18.841338 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.27s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.89s
# I1223 08:44:20.729137 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.89s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I1223 08:44:20.735326 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# I1223 08:44:20.759577 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# I1223 08:44:20.775340 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# I1223 08:44:20.793344 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.25s
# I1223 08:44:21.043433 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.25s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.09s
# I1223 08:44:21.136555 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.1s
# I1223 08:44:21.234248 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.1s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.11s
# I1223 08:44:21.339998 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.11s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.09s
# I1223 08:44:21.435359 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# I1223 08:44:21.464184 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I1223 08:44:21.644976 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b0
# I1223 08:44:21.645135 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 64
# I1223 08:44:21.645205 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 3
# I1223 08:44:21.647363 140694111016832 efficientnet_model.py:143] round_filter input=32 output=32
# I1223 08:44:21.673367 140694111016832 efficientnet_model.py:143] round_filter input=32 output=32
# I1223 08:44:21.673492 140694111016832 efficientnet_model.py:143] round_filter input=16 output=16
# I1223 08:44:21.755881 140694111016832 efficientnet_model.py:143] round_filter input=16 output=16
# I1223 08:44:21.756056 140694111016832 efficientnet_model.py:143] round_filter input=24 output=24
# I1223 08:44:21.945147 140694111016832 efficientnet_model.py:143] round_filter input=24 output=24
# I1223 08:44:21.945318 140694111016832 efficientnet_model.py:143] round_filter input=40 output=40
# I1223 08:44:22.120485 140694111016832 efficientnet_model.py:143] round_filter input=40 output=40
# I1223 08:44:22.120656 140694111016832 efficientnet_model.py:143] round_filter input=80 output=80
# I1223 08:44:22.386840 140694111016832 efficientnet_model.py:143] round_filter input=80 output=80
# I1223 08:44:22.387020 140694111016832 efficientnet_model.py:143] round_filter input=112 output=112
# I1223 08:44:22.659298 140694111016832 efficientnet_model.py:143] round_filter input=112 output=112
# I1223 08:44:22.659491 140694111016832 efficientnet_model.py:143] round_filter input=192 output=192
# I1223 08:44:23.010069 140694111016832 efficientnet_model.py:143] round_filter input=192 output=192
# I1223 08:44:23.010263 140694111016832 efficientnet_model.py:143] round_filter input=320 output=320
# I1223 08:44:23.092203 140694111016832 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1223 08:44:23.131528 140694111016832 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1223 08:44:23.179973 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b1
# I1223 08:44:23.180112 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 88
# I1223 08:44:23.180182 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 4
# I1223 08:44:23.181693 140694111016832 efficientnet_model.py:143] round_filter input=32 output=32
# I1223 08:44:23.197376 140694111016832 efficientnet_model.py:143] round_filter input=32 output=32
# I1223 08:44:23.197493 140694111016832 efficientnet_model.py:143] round_filter input=16 output=16
# I1223 08:44:23.338024 140694111016832 efficientnet_model.py:143] round_filter input=16 output=16
# I1223 08:44:23.338217 140694111016832 efficientnet_model.py:143] round_filter input=24 output=24
# I1223 08:44:23.585571 140694111016832 efficientnet_model.py:143] round_filter input=24 output=24
# I1223 08:44:23.585747 140694111016832 efficientnet_model.py:143] round_filter input=40 output=40
# I1223 08:44:23.840723 140694111016832 efficientnet_model.py:143] round_filter input=40 output=40
# I1223 08:44:23.840896 140694111016832 efficientnet_model.py:143] round_filter input=80 output=80
# I1223 08:44:24.172107 140694111016832 efficientnet_model.py:143] round_filter input=80 output=80
# I1223 08:44:24.172264 140694111016832 efficientnet_model.py:143] round_filter input=112 output=112
# I1223 08:44:24.505419 140694111016832 efficientnet_model.py:143] round_filter input=112 output=112
# I1223 08:44:24.505587 140694111016832 efficientnet_model.py:143] round_filter input=192 output=192
# I1223 08:44:24.928085 140694111016832 efficientnet_model.py:143] round_filter input=192 output=192
# I1223 08:44:24.928288 140694111016832 efficientnet_model.py:143] round_filter input=320 output=320
# I1223 08:44:25.097747 140694111016832 efficientnet_model.py:143] round_filter input=1280 output=1280
# I1223 08:44:25.131231 140694111016832 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1223 08:44:25.189111 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b2
# I1223 08:44:25.189256 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 112
# I1223 08:44:25.189331 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 5
# I1223 08:44:25.190989 140694111016832 efficientnet_model.py:143] round_filter input=32 output=32
# I1223 08:44:25.208106 140694111016832 efficientnet_model.py:143] round_filter input=32 output=32
# I1223 08:44:25.208222 140694111016832 efficientnet_model.py:143] round_filter input=16 output=16
# I1223 08:44:25.341137 140694111016832 efficientnet_model.py:143] round_filter input=16 output=16
# I1223 08:44:25.341289 140694111016832 efficientnet_model.py:143] round_filter input=24 output=24
# I1223 08:44:25.592049 140694111016832 efficientnet_model.py:143] round_filter input=24 output=24
# I1223 08:44:25.592213 140694111016832 efficientnet_model.py:143] round_filter input=40 output=48
# I1223 08:44:26.011351 140694111016832 efficientnet_model.py:143] round_filter input=40 output=48
# I1223 08:44:26.011519 140694111016832 efficientnet_model.py:143] round_filter input=80 output=88
# I1223 08:44:26.357760 140694111016832 efficientnet_model.py:143] round_filter input=80 output=88
# I1223 08:44:26.357923 140694111016832 efficientnet_model.py:143] round_filter input=112 output=120
# I1223 08:44:26.707262 140694111016832 efficientnet_model.py:143] round_filter input=112 output=120
# I1223 08:44:26.707434 140694111016832 efficientnet_model.py:143] round_filter input=192 output=208
# I1223 08:44:27.129251 140694111016832 efficientnet_model.py:143] round_filter input=192 output=208
# I1223 08:44:27.129429 140694111016832 efficientnet_model.py:143] round_filter input=320 output=352
# I1223 08:44:27.297465 140694111016832 efficientnet_model.py:143] round_filter input=1280 output=1408
# I1223 08:44:27.335482 140694111016832 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1223 08:44:27.389789 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b3
# I1223 08:44:27.389948 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 160
# I1223 08:44:27.390032 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 6
# I1223 08:44:27.391578 140694111016832 efficientnet_model.py:143] round_filter input=32 output=40
# I1223 08:44:27.410532 140694111016832 efficientnet_model.py:143] round_filter input=32 output=40
# I1223 08:44:27.410662 140694111016832 efficientnet_model.py:143] round_filter input=16 output=24
# I1223 08:44:27.550333 140694111016832 efficientnet_model.py:143] round_filter input=16 output=24
# I1223 08:44:27.550490 140694111016832 efficientnet_model.py:143] round_filter input=24 output=32
# I1223 08:44:27.803730 140694111016832 efficientnet_model.py:143] round_filter input=24 output=32
# I1223 08:44:27.803894 140694111016832 efficientnet_model.py:143] round_filter input=40 output=48
# I1223 08:44:28.059094 140694111016832 efficientnet_model.py:143] round_filter input=40 output=48
# I1223 08:44:28.059273 140694111016832 efficientnet_model.py:143] round_filter input=80 output=96
# I1223 08:44:28.473205 140694111016832 efficientnet_model.py:143] round_filter input=80 output=96
# I1223 08:44:28.473378 140694111016832 efficientnet_model.py:143] round_filter input=112 output=136
# I1223 08:44:28.892413 140694111016832 efficientnet_model.py:143] round_filter input=112 output=136
# I1223 08:44:28.892576 140694111016832 efficientnet_model.py:143] round_filter input=192 output=232
# I1223 08:44:29.401566 140694111016832 efficientnet_model.py:143] round_filter input=192 output=232
# I1223 08:44:29.401749 140694111016832 efficientnet_model.py:143] round_filter input=320 output=384
# I1223 08:44:29.575652 140694111016832 efficientnet_model.py:143] round_filter input=1280 output=1536
# I1223 08:44:29.613265 140694111016832 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1223 08:44:29.677308 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b4
# I1223 08:44:29.677460 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 224
# I1223 08:44:29.677537 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I1223 08:44:29.679092 140694111016832 efficientnet_model.py:143] round_filter input=32 output=48
# I1223 08:44:29.697953 140694111016832 efficientnet_model.py:143] round_filter input=32 output=48
# I1223 08:44:29.698060 140694111016832 efficientnet_model.py:143] round_filter input=16 output=24
# I1223 08:44:29.830043 140694111016832 efficientnet_model.py:143] round_filter input=16 output=24
# I1223 08:44:29.830178 140694111016832 efficientnet_model.py:143] round_filter input=24 output=32
# I1223 08:44:30.153579 140694111016832 efficientnet_model.py:143] round_filter input=24 output=32
# I1223 08:44:30.153753 140694111016832 efficientnet_model.py:143] round_filter input=40 output=56
# I1223 08:44:30.501931 140694111016832 efficientnet_model.py:143] round_filter input=40 output=56
# I1223 08:44:30.502111 140694111016832 efficientnet_model.py:143] round_filter input=80 output=112
# I1223 08:44:31.014454 140694111016832 efficientnet_model.py:143] round_filter input=80 output=112
# I1223 08:44:31.014621 140694111016832 efficientnet_model.py:143] round_filter input=112 output=160
# I1223 08:44:31.520878 140694111016832 efficientnet_model.py:143] round_filter input=112 output=160
# I1223 08:44:31.521057 140694111016832 efficientnet_model.py:143] round_filter input=192 output=272
# I1223 08:44:32.415572 140694111016832 efficientnet_model.py:143] round_filter input=192 output=272
# I1223 08:44:32.415754 140694111016832 efficientnet_model.py:143] round_filter input=320 output=448
# I1223 08:44:32.587861 140694111016832 efficientnet_model.py:143] round_filter input=1280 output=1792
# I1223 08:44:32.622386 140694111016832 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1223 08:44:32.696687 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b5
# I1223 08:44:32.696856 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 288
# I1223 08:44:32.696938 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I1223 08:44:32.698807 140694111016832 efficientnet_model.py:143] round_filter input=32 output=48
# I1223 08:44:32.715945 140694111016832 efficientnet_model.py:143] round_filter input=32 output=48
# I1223 08:44:32.716093 140694111016832 efficientnet_model.py:143] round_filter input=16 output=24
# I1223 08:44:32.908798 140694111016832 efficientnet_model.py:143] round_filter input=16 output=24
# I1223 08:44:32.908957 140694111016832 efficientnet_model.py:143] round_filter input=24 output=40
# I1223 08:44:33.335344 140694111016832 efficientnet_model.py:143] round_filter input=24 output=40
# I1223 08:44:33.335534 140694111016832 efficientnet_model.py:143] round_filter input=40 output=64
# I1223 08:44:33.759197 140694111016832 efficientnet_model.py:143] round_filter input=40 output=64
# I1223 08:44:33.759396 140694111016832 efficientnet_model.py:143] round_filter input=80 output=128
# I1223 08:44:34.376771 140694111016832 efficientnet_model.py:143] round_filter input=80 output=128
# I1223 08:44:34.376936 140694111016832 efficientnet_model.py:143] round_filter input=112 output=176
# I1223 08:44:34.966656 140694111016832 efficientnet_model.py:143] round_filter input=112 output=176
# I1223 08:44:34.966818 140694111016832 efficientnet_model.py:143] round_filter input=192 output=304
# I1223 08:44:35.777735 140694111016832 efficientnet_model.py:143] round_filter input=192 output=304
# I1223 08:44:35.777903 140694111016832 efficientnet_model.py:143] round_filter input=320 output=512
# I1223 08:44:36.041091 140694111016832 efficientnet_model.py:143] round_filter input=1280 output=2048
# I1223 08:44:36.078738 140694111016832 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1223 08:44:36.155261 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b6
# I1223 08:44:36.155422 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I1223 08:44:36.155498 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I1223 08:44:36.157048 140694111016832 efficientnet_model.py:143] round_filter input=32 output=56
# I1223 08:44:36.175584 140694111016832 efficientnet_model.py:143] round_filter input=32 output=56
# I1223 08:44:36.175712 140694111016832 efficientnet_model.py:143] round_filter input=16 output=32
# I1223 08:44:36.389639 140694111016832 efficientnet_model.py:143] round_filter input=16 output=32
# I1223 08:44:36.389820 140694111016832 efficientnet_model.py:143] round_filter input=24 output=40
# I1223 08:44:36.930094 140694111016832 efficientnet_model.py:143] round_filter input=24 output=40
# I1223 08:44:36.930274 140694111016832 efficientnet_model.py:143] round_filter input=40 output=72
# I1223 08:44:37.453730 140694111016832 efficientnet_model.py:143] round_filter input=40 output=72
# I1223 08:44:37.453904 140694111016832 efficientnet_model.py:143] round_filter input=80 output=144
# I1223 08:44:38.137584 140694111016832 efficientnet_model.py:143] round_filter input=80 output=144
# I1223 08:44:38.137767 140694111016832 efficientnet_model.py:143] round_filter input=112 output=200
# I1223 08:44:39.069628 140694111016832 efficientnet_model.py:143] round_filter input=112 output=200
# I1223 08:44:39.069829 140694111016832 efficientnet_model.py:143] round_filter input=192 output=344
# I1223 08:44:40.017194 140694111016832 efficientnet_model.py:143] round_filter input=192 output=344
# I1223 08:44:40.017366 140694111016832 efficientnet_model.py:143] round_filter input=320 output=576
# I1223 08:44:40.279755 140694111016832 efficientnet_model.py:143] round_filter input=1280 output=2304
# I1223 08:44:40.323412 140694111016832 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1223 08:44:40.416494 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b7
# I1223 08:44:40.416666 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I1223 08:44:40.416742 140694111016832 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I1223 08:44:40.418319 140694111016832 efficientnet_model.py:143] round_filter input=32 output=64
# I1223 08:44:40.439425 140694111016832 efficientnet_model.py:143] round_filter input=32 output=64
# I1223 08:44:40.439553 140694111016832 efficientnet_model.py:143] round_filter input=16 output=32
# I1223 08:44:40.732140 140694111016832 efficientnet_model.py:143] round_filter input=16 output=32
# I1223 08:44:40.732316 140694111016832 efficientnet_model.py:143] round_filter input=24 output=48
# I1223 08:44:41.324098 140694111016832 efficientnet_model.py:143] round_filter input=24 output=48
# I1223 08:44:41.324264 140694111016832 efficientnet_model.py:143] round_filter input=40 output=80
# I1223 08:44:41.914073 140694111016832 efficientnet_model.py:143] round_filter input=40 output=80
# I1223 08:44:41.914239 140694111016832 efficientnet_model.py:143] round_filter input=80 output=160
# I1223 08:44:42.773882 140694111016832 efficientnet_model.py:143] round_filter input=80 output=160
# I1223 08:44:42.774055 140694111016832 efficientnet_model.py:143] round_filter input=112 output=224
# I1223 08:44:43.621309 140694111016832 efficientnet_model.py:143] round_filter input=112 output=224
# I1223 08:44:43.621500 140694111016832 efficientnet_model.py:143] round_filter input=192 output=384
# I1223 08:44:44.690795 140694111016832 efficientnet_model.py:143] round_filter input=192 output=384
# I1223 08:44:44.690974 140694111016832 efficientnet_model.py:143] round_filter input=320 output=640
# I1223 08:44:45.031051 140694111016832 efficientnet_model.py:143] round_filter input=1280 output=2560
# I1223 08:44:45.066707 140694111016832 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 23.96s
# I1223 08:44:45.421685 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 23.96s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I1223 08:44:45.447481 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I1223 08:44:45.449117 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I1223 08:44:45.449590 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I1223 08:44:45.450938 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I1223 08:44:45.452146 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I1223 08:44:45.452548 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I1223 08:44:45.453443 140694111016832 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 29.344s
#
# OK (skipped=1)

# %%
cd /content/training_demo/pre-trained-models
# Out:
# /content/training_demo/pre-trained-models

# %%
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Out:
# --2022-12-23 09:12:02--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 173.194.217.128, 2607:f8b0:400c:c13::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|173.194.217.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  --.-KB/s    in 0.1s
#
# 2022-12-23 09:12:03 (136 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]

# %%
# !tar -xvf ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Out:
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %%
pwd
# Out:
# '/content/training_demo/pre-trained-models'

# %%
cd /content/training_demo
# Out:
# /content/training_demo

# %%
# Create train data:
# !python generate_tfrecord.py -x /content/training_demo/images/train -l /content/training_demo/annotations/label_map.pbtxt -o /content/training_demo/annotations/train.record

# Create test data:
# !python generate_tfrecord.py -x /content/training_demo/images/test -l /content/training_demo/annotations/label_map.pbtxt -o /content/training_demo/annotations/test.record
# Out:
# Successfully created the TFRecord file: /content/training_demo/annotations/train.record
# Successfully created the TFRecord file: /content/training_demo/annotations/test.record

# %%
pwd
# Out:
# '/content/training_demo'

# %%
ls
# Out:
# annotations/         export_tflite_graph_tf2.py  model_main_tf2.py
# exported_models/     generate_tfrecord.py        models/
# exporter_main_v2.py  images/                     pre-trained-models/

# %%
# !python model_main_tf2.py --model_dir=/content/training_demo/models/my_ssd_mobilenet_v2_fpnlite --pipeline_config_path=/content/training_demo/models/my_ssd_mobilenet_v2_fpnlite/pipeline.config
# Out:
# 2022-12-23 09:50:19.864301: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-23 09:50:19.864414: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-23 09:50:19.864433: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-12-23 09:50:23.422632: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I1223 09:50:23.437593 140143723599744 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I1223 09:50:23.441370 140143723599744 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1223 09:50:23.441530 140143723599744 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W1223 09:50:23.465818 140143723599744 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/content/training_demo/annotations/train.record']
# I1223 09:50:23.472788 140143723599744 dataset_builder.py:162] Reading unweighted datasets: ['/content/training_demo/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['/content/training_demo/annotations/train.record']
# I1223 09:50:23.472980 140143723599744 dataset_builder.py:79] Reading record datasets for input file: ['/content/training_demo/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1223 09:50:23.473066 140143723599744 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1223 09:50:23.473136 140143723599744 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1223 09:50:23.478483 140143723599744 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1223 09:50:23.494521 140143723599744 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W1223 09:50:24.030544 140143723599744 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1223 09:50:29.532893 140143723599744 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W1223 09:50:32.042143 140143723599744 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1223 09:50:33.470802 140143723599744 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.8/dist-packages/keras/backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1223 09:51:03.233393 140143723599744 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1223 09:51:03.235988 140143723599744 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1223 09:51:03.237221 140143723599744 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1223 09:51:03.238220 140143723599744 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1223 09:51:03.241579 140143723599744 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1223 09:51:03.242527 140143723599744 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1223 09:51:03.243507 140143723599744 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1223 09:51:03.244446 140143723599744 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1223 09:51:03.248618 140143723599744 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1223 09:51:03.249554 140143723599744 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W1223 09:51:04.406499 140139279922944 deprecation.py:554] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 0.466s
# I1223 09:51:50.684808 140143723599744 model_lib_v2.py:705] Step 100 per-step time 0.466s
# INFO:tensorflow:{'Loss/classification_loss': 0.2808298,
#  'Loss/localization_loss': 0.20863792,
#  'Loss/regularization_loss': 0.15350589,
#  'Loss/total_loss': 0.6429736,
#  'learning_rate': 0.0319994}
# I1223 09:51:50.685149 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.2808298,
#  'Loss/localization_loss': 0.20863792,
#  'Loss/regularization_loss': 0.15350589,
#  'Loss/total_loss': 0.6429736,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.111s
# I1223 09:52:01.748947 140143723599744 model_lib_v2.py:705] Step 200 per-step time 0.111s
# INFO:tensorflow:{'Loss/classification_loss': 0.19679052,
#  'Loss/localization_loss': 0.2375727,
#  'Loss/regularization_loss': 0.15340357,
#  'Loss/total_loss': 0.58776677,
#  'learning_rate': 0.0373328}
# I1223 09:52:01.749322 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.19679052,
#  'Loss/localization_loss': 0.2375727,
#  'Loss/regularization_loss': 0.15340357,
#  'Loss/total_loss': 0.58776677,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.130s
# I1223 09:52:14.756888 140143723599744 model_lib_v2.py:705] Step 300 per-step time 0.130s
# INFO:tensorflow:{'Loss/classification_loss': 0.18958555,
#  'Loss/localization_loss': 0.18145382,
#  'Loss/regularization_loss': 0.15336707,
#  'Loss/total_loss': 0.52440643,
#  'learning_rate': 0.0426662}
# I1223 09:52:14.757265 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.18958555,
#  'Loss/localization_loss': 0.18145382,
#  'Loss/regularization_loss': 0.15336707,
#  'Loss/total_loss': 0.52440643,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.118s
# I1223 09:52:26.535063 140143723599744 model_lib_v2.py:705] Step 400 per-step time 0.118s
# INFO:tensorflow:{'Loss/classification_loss': 0.1857366,
#  'Loss/localization_loss': 0.13287191,
#  'Loss/regularization_loss': 0.1533034,
#  'Loss/total_loss': 0.4719119,
#  'learning_rate': 0.047999598}
# I1223 09:52:26.535361 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.1857366,
#  'Loss/localization_loss': 0.13287191,
#  'Loss/regularization_loss': 0.1533034,
#  'Loss/total_loss': 0.4719119,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.112s
# I1223 09:52:37.781558 140143723599744 model_lib_v2.py:705] Step 500 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.18857256,
#  'Loss/localization_loss': 0.22045524,
#  'Loss/regularization_loss': 0.15321831,
#  'Loss/total_loss': 0.56224614,
#  'learning_rate': 0.053333}
# I1223 09:52:37.781867 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.18857256,
#  'Loss/localization_loss': 0.22045524,
#  'Loss/regularization_loss': 0.15321831,
#  'Loss/total_loss': 0.56224614,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.113s
# I1223 09:52:49.037487 140143723599744 model_lib_v2.py:705] Step 600 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.21396734,
#  'Loss/localization_loss': 0.09039984,
#  'Loss/regularization_loss': 0.15310918,
#  'Loss/total_loss': 0.45747638,
#  'learning_rate': 0.0586664}
# I1223 09:52:49.037856 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.21396734,
#  'Loss/localization_loss': 0.09039984,
#  'Loss/regularization_loss': 0.15310918,
#  'Loss/total_loss': 0.45747638,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.113s
# I1223 09:53:00.370149 140143723599744 model_lib_v2.py:705] Step 700 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.1932463,
#  'Loss/localization_loss': 0.12106158,
#  'Loss/regularization_loss': 0.15288188,
#  'Loss/total_loss': 0.46718973,
#  'learning_rate': 0.0639998}
# I1223 09:53:00.370445 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.1932463,
#  'Loss/localization_loss': 0.12106158,
#  'Loss/regularization_loss': 0.15288188,
#  'Loss/total_loss': 0.46718973,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.114s
# I1223 09:53:11.737104 140143723599744 model_lib_v2.py:705] Step 800 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.16773003,
#  'Loss/localization_loss': 0.118431754,
#  'Loss/regularization_loss': 0.15301795,
#  'Loss/total_loss': 0.43917972,
#  'learning_rate': 0.069333196}
# I1223 09:53:11.737390 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.16773003,
#  'Loss/localization_loss': 0.118431754,
#  'Loss/regularization_loss': 0.15301795,
#  'Loss/total_loss': 0.43917972,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.113s
# I1223 09:53:23.054386 140143723599744 model_lib_v2.py:705] Step 900 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.25248665,
#  'Loss/localization_loss': 0.14993747,
#  'Loss/regularization_loss': 0.15299061,
#  'Loss/total_loss': 0.5554147,
#  'learning_rate': 0.074666604}
# I1223 09:53:23.054701 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.25248665,
#  'Loss/localization_loss': 0.14993747,
#  'Loss/regularization_loss': 0.15299061,
#  'Loss/total_loss': 0.5554147,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.113s
# I1223 09:53:34.321278 140143723599744 model_lib_v2.py:705] Step 1000 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.1541793,
#  'Loss/localization_loss': 0.11402066,
#  'Loss/regularization_loss': 0.15267986,
#  'Loss/total_loss': 0.42087984,
#  'learning_rate': 0.08}
# I1223 09:53:34.321576 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.1541793,
#  'Loss/localization_loss': 0.11402066,
#  'Loss/regularization_loss': 0.15267986,
#  'Loss/total_loss': 0.42087984,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.124s
# I1223 09:53:46.750161 140143723599744 model_lib_v2.py:705] Step 1100 per-step time 0.124s
# INFO:tensorflow:{'Loss/classification_loss': 0.14268777,
#  'Loss/localization_loss': 0.11710053,
#  'Loss/regularization_loss': 0.1525679,
#  'Loss/total_loss': 0.4123562,
#  'learning_rate': 0.07987669}
# I1223 09:53:46.750466 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.14268777,
#  'Loss/localization_loss': 0.11710053,
#  'Loss/regularization_loss': 0.1525679,
#  'Loss/total_loss': 0.4123562,
#  'learning_rate': 0.07987669}
# INFO:tensorflow:Step 1200 per-step time 0.112s
# I1223 09:53:57.949874 140143723599744 model_lib_v2.py:705] Step 1200 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.14985622,
#  'Loss/localization_loss': 0.13120176,
#  'Loss/regularization_loss': 0.1521461,
#  'Loss/total_loss': 0.43320408,
#  'learning_rate': 0.07950753}
# I1223 09:53:57.950174 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.14985622,
#  'Loss/localization_loss': 0.13120176,
#  'Loss/regularization_loss': 0.1521461,
#  'Loss/total_loss': 0.43320408,
#  'learning_rate': 0.07950753}
# INFO:tensorflow:Step 1300 per-step time 0.113s
# I1223 09:54:09.294767 140143723599744 model_lib_v2.py:705] Step 1300 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.1309117,
#  'Loss/localization_loss': 0.08763476,
#  'Loss/regularization_loss': 0.15165748,
#  'Loss/total_loss': 0.3702039,
#  'learning_rate': 0.078894794}
# I1223 09:54:09.295072 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.1309117,
#  'Loss/localization_loss': 0.08763476,
#  'Loss/regularization_loss': 0.15165748,
#  'Loss/total_loss': 0.3702039,
#  'learning_rate': 0.078894794}
# INFO:tensorflow:Step 1400 per-step time 0.113s
# I1223 09:54:20.596582 140143723599744 model_lib_v2.py:705] Step 1400 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.11396532,
#  'Loss/localization_loss': 0.067800455,
#  'Loss/regularization_loss': 0.15117882,
#  'Loss/total_loss': 0.33294457,
#  'learning_rate': 0.078042254}
# I1223 09:54:20.596906 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.11396532,
#  'Loss/localization_loss': 0.067800455,
#  'Loss/regularization_loss': 0.15117882,
#  'Loss/total_loss': 0.33294457,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 1500 per-step time 0.113s
# I1223 09:54:31.937542 140143723599744 model_lib_v2.py:705] Step 1500 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.11996411,
#  'Loss/localization_loss': 0.04673425,
#  'Loss/regularization_loss': 0.15077193,
#  'Loss/total_loss': 0.3174703,
#  'learning_rate': 0.076955184}
# I1223 09:54:31.937845 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.11996411,
#  'Loss/localization_loss': 0.04673425,
#  'Loss/regularization_loss': 0.15077193,
#  'Loss/total_loss': 0.3174703,
#  'learning_rate': 0.076955184}
# INFO:tensorflow:Step 1600 per-step time 0.113s
# I1223 09:54:43.254549 140143723599744 model_lib_v2.py:705] Step 1600 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.087741055,
#  'Loss/localization_loss': 0.044085294,
#  'Loss/regularization_loss': 0.15021595,
#  'Loss/total_loss': 0.2820423,
#  'learning_rate': 0.07564025}
# I1223 09:54:43.254855 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.087741055,
#  'Loss/localization_loss': 0.044085294,
#  'Loss/regularization_loss': 0.15021595,
#  'Loss/total_loss': 0.2820423,
#  'learning_rate': 0.07564025}
# INFO:tensorflow:Step 1700 per-step time 0.112s
# I1223 09:54:54.487191 140143723599744 model_lib_v2.py:705] Step 1700 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.17368066,
#  'Loss/localization_loss': 0.12025125,
#  'Loss/regularization_loss': 0.14972354,
#  'Loss/total_loss': 0.44365543,
#  'learning_rate': 0.074105605}
# I1223 09:54:54.487475 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.17368066,
#  'Loss/localization_loss': 0.12025125,
#  'Loss/regularization_loss': 0.14972354,
#  'Loss/total_loss': 0.44365543,
#  'learning_rate': 0.074105605}
# INFO:tensorflow:Step 1800 per-step time 0.113s
# I1223 09:55:05.771195 140143723599744 model_lib_v2.py:705] Step 1800 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.106606565,
#  'Loss/localization_loss': 0.08527213,
#  'Loss/regularization_loss': 0.14927848,
#  'Loss/total_loss': 0.3411572,
#  'learning_rate': 0.07236068}
# I1223 09:55:05.771498 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.106606565,
#  'Loss/localization_loss': 0.08527213,
#  'Loss/regularization_loss': 0.14927848,
#  'Loss/total_loss': 0.3411572,
#  'learning_rate': 0.07236068}
# INFO:tensorflow:Step 1900 per-step time 0.135s
# I1223 09:55:19.235446 140143723599744 model_lib_v2.py:705] Step 1900 per-step time 0.135s
# INFO:tensorflow:{'Loss/classification_loss': 0.105205774,
#  'Loss/localization_loss': 0.059903845,
#  'Loss/regularization_loss': 0.14868435,
#  'Loss/total_loss': 0.31379396,
#  'learning_rate': 0.07041624}
# I1223 09:55:19.235755 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.105205774,
#  'Loss/localization_loss': 0.059903845,
#  'Loss/regularization_loss': 0.14868435,
#  'Loss/total_loss': 0.31379396,
#  'learning_rate': 0.07041624}
# INFO:tensorflow:Step 2000 per-step time 0.113s
# I1223 09:55:30.540450 140143723599744 model_lib_v2.py:705] Step 2000 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.15872487,
#  'Loss/localization_loss': 0.08266236,
#  'Loss/regularization_loss': 0.14811152,
#  'Loss/total_loss': 0.38949877,
#  'learning_rate': 0.06828427}
# I1223 09:55:30.540768 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.15872487,
#  'Loss/localization_loss': 0.08266236,
#  'Loss/regularization_loss': 0.14811152,
#  'Loss/total_loss': 0.38949877,
#  'learning_rate': 0.06828427}
# INFO:tensorflow:Step 2100 per-step time 0.124s
# I1223 09:55:42.891924 140143723599744 model_lib_v2.py:705] Step 2100 per-step time 0.124s
# INFO:tensorflow:{'Loss/classification_loss': 0.11810105,
#  'Loss/localization_loss': 0.08333888,
#  'Loss/regularization_loss': 0.14758201,
#  'Loss/total_loss': 0.34902194,
#  'learning_rate': 0.06597792}
# I1223 09:55:42.892228 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.11810105,
#  'Loss/localization_loss': 0.08333888,
#  'Loss/regularization_loss': 0.14758201,
#  'Loss/total_loss': 0.34902194,
#  'learning_rate': 0.06597792}
# INFO:tensorflow:Step 2200 per-step time 0.113s
# I1223 09:55:54.236058 140143723599744 model_lib_v2.py:705] Step 2200 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.08118387,
#  'Loss/localization_loss': 0.03665093,
#  'Loss/regularization_loss': 0.14706603,
#  'Loss/total_loss': 0.26490083,
#  'learning_rate': 0.06351141}
# I1223 09:55:54.236363 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.08118387,
#  'Loss/localization_loss': 0.03665093,
#  'Loss/regularization_loss': 0.14706603,
#  'Loss/total_loss': 0.26490083,
#  'learning_rate': 0.06351141}
# INFO:tensorflow:Step 2300 per-step time 0.114s
# I1223 09:56:05.630138 140143723599744 model_lib_v2.py:705] Step 2300 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.078355245,
#  'Loss/localization_loss': 0.042997047,
#  'Loss/regularization_loss': 0.14652139,
#  'Loss/total_loss': 0.26787367,
#  'learning_rate': 0.06089994}
# I1223 09:56:05.630468 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.078355245,
#  'Loss/localization_loss': 0.042997047,
#  'Loss/regularization_loss': 0.14652139,
#  'Loss/total_loss': 0.26787367,
#  'learning_rate': 0.06089994}
# INFO:tensorflow:Step 2400 per-step time 0.112s
# I1223 09:56:16.861394 140143723599744 model_lib_v2.py:705] Step 2400 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.07027894,
#  'Loss/localization_loss': 0.04181579,
#  'Loss/regularization_loss': 0.1459868,
#  'Loss/total_loss': 0.25808153,
#  'learning_rate': 0.058159616}
# I1223 09:56:16.861711 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.07027894,
#  'Loss/localization_loss': 0.04181579,
#  'Loss/regularization_loss': 0.1459868,
#  'Loss/total_loss': 0.25808153,
#  'learning_rate': 0.058159616}
# INFO:tensorflow:Step 2500 per-step time 0.114s
# I1223 09:56:28.223989 140143723599744 model_lib_v2.py:705] Step 2500 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.110555395,
#  'Loss/localization_loss': 0.079969384,
#  'Loss/regularization_loss': 0.14546537,
#  'Loss/total_loss': 0.33599016,
#  'learning_rate': 0.05530734}
# I1223 09:56:28.224284 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.110555395,
#  'Loss/localization_loss': 0.079969384,
#  'Loss/regularization_loss': 0.14546537,
#  'Loss/total_loss': 0.33599016,
#  'learning_rate': 0.05530734}
# INFO:tensorflow:Step 2600 per-step time 0.113s
# I1223 09:56:39.549536 140143723599744 model_lib_v2.py:705] Step 2600 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.06357522,
#  'Loss/localization_loss': 0.021313045,
#  'Loss/regularization_loss': 0.14494842,
#  'Loss/total_loss': 0.22983669,
#  'learning_rate': 0.052360676}
# I1223 09:56:39.549830 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.06357522,
#  'Loss/localization_loss': 0.021313045,
#  'Loss/regularization_loss': 0.14494842,
#  'Loss/total_loss': 0.22983669,
#  'learning_rate': 0.052360676}
# INFO:tensorflow:Step 2700 per-step time 0.113s
# I1223 09:56:50.803717 140143723599744 model_lib_v2.py:705] Step 2700 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.085229,
#  'Loss/localization_loss': 0.030059662,
#  'Loss/regularization_loss': 0.1444437,
#  'Loss/total_loss': 0.25973237,
#  'learning_rate': 0.049337815}
# I1223 09:56:50.804008 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.085229,
#  'Loss/localization_loss': 0.030059662,
#  'Loss/regularization_loss': 0.1444437,
#  'Loss/total_loss': 0.25973237,
#  'learning_rate': 0.049337815}
# INFO:tensorflow:Step 2800 per-step time 0.113s
# I1223 09:57:02.087749 140143723599744 model_lib_v2.py:705] Step 2800 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.08058019,
#  'Loss/localization_loss': 0.052296925,
#  'Loss/regularization_loss': 0.14397676,
#  'Loss/total_loss': 0.27685386,
#  'learning_rate': 0.04625738}
# I1223 09:57:02.088047 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.08058019,
#  'Loss/localization_loss': 0.052296925,
#  'Loss/regularization_loss': 0.14397676,
#  'Loss/total_loss': 0.27685386,
#  'learning_rate': 0.04625738}
# INFO:tensorflow:Step 2900 per-step time 0.113s
# I1223 09:57:13.398064 140143723599744 model_lib_v2.py:705] Step 2900 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.13121352,
#  'Loss/localization_loss': 0.0383923,
#  'Loss/regularization_loss': 0.14352638,
#  'Loss/total_loss': 0.3131322,
#  'learning_rate': 0.04313836}
# I1223 09:57:13.398374 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.13121352,
#  'Loss/localization_loss': 0.0383923,
#  'Loss/regularization_loss': 0.14352638,
#  'Loss/total_loss': 0.3131322,
#  'learning_rate': 0.04313836}
# INFO:tensorflow:Step 3000 per-step time 0.112s
# I1223 09:57:24.578227 140143723599744 model_lib_v2.py:705] Step 3000 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.07671954,
#  'Loss/localization_loss': 0.02526988,
#  'Loss/regularization_loss': 0.14311291,
#  'Loss/total_loss': 0.24510233,
#  'learning_rate': 0.039999995}
# I1223 09:57:24.578517 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.07671954,
#  'Loss/localization_loss': 0.02526988,
#  'Loss/regularization_loss': 0.14311291,
#  'Loss/total_loss': 0.24510233,
#  'learning_rate': 0.039999995}
# INFO:tensorflow:Step 3100 per-step time 0.124s
# I1223 09:57:36.933417 140143723599744 model_lib_v2.py:705] Step 3100 per-step time 0.124s
# INFO:tensorflow:{'Loss/classification_loss': 0.06134829,
#  'Loss/localization_loss': 0.03752622,
#  'Loss/regularization_loss': 0.14272022,
#  'Loss/total_loss': 0.24159473,
#  'learning_rate': 0.036861632}
# I1223 09:57:36.933767 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.06134829,
#  'Loss/localization_loss': 0.03752622,
#  'Loss/regularization_loss': 0.14272022,
#  'Loss/total_loss': 0.24159473,
#  'learning_rate': 0.036861632}
# INFO:tensorflow:Step 3200 per-step time 0.113s
# I1223 09:57:48.271789 140143723599744 model_lib_v2.py:705] Step 3200 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.07641738,
#  'Loss/localization_loss': 0.05890386,
#  'Loss/regularization_loss': 0.14236157,
#  'Loss/total_loss': 0.2776828,
#  'learning_rate': 0.03374262}
# I1223 09:57:48.272085 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.07641738,
#  'Loss/localization_loss': 0.05890386,
#  'Loss/regularization_loss': 0.14236157,
#  'Loss/total_loss': 0.2776828,
#  'learning_rate': 0.03374262}
# INFO:tensorflow:Step 3300 per-step time 0.113s
# I1223 09:57:59.546452 140143723599744 model_lib_v2.py:705] Step 3300 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.04982202,
#  'Loss/localization_loss': 0.023869889,
#  'Loss/regularization_loss': 0.14202687,
#  'Loss/total_loss': 0.21571878,
#  'learning_rate': 0.030662183}
# I1223 09:57:59.546797 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.04982202,
#  'Loss/localization_loss': 0.023869889,
#  'Loss/regularization_loss': 0.14202687,
#  'Loss/total_loss': 0.21571878,
#  'learning_rate': 0.030662183}
# INFO:tensorflow:Step 3400 per-step time 0.137s
# I1223 09:58:13.198065 140143723599744 model_lib_v2.py:705] Step 3400 per-step time 0.137s
# INFO:tensorflow:{'Loss/classification_loss': 0.08849947,
#  'Loss/localization_loss': 0.06346328,
#  'Loss/regularization_loss': 0.14171883,
#  'Loss/total_loss': 0.2936816,
#  'learning_rate': 0.027639316}
# I1223 09:58:13.198365 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.08849947,
#  'Loss/localization_loss': 0.06346328,
#  'Loss/regularization_loss': 0.14171883,
#  'Loss/total_loss': 0.2936816,
#  'learning_rate': 0.027639316}
# INFO:tensorflow:Step 3500 per-step time 0.112s
# I1223 09:58:24.402684 140143723599744 model_lib_v2.py:705] Step 3500 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.06645182,
#  'Loss/localization_loss': 0.018248761,
#  'Loss/regularization_loss': 0.14144424,
#  'Loss/total_loss': 0.22614482,
#  'learning_rate': 0.024692658}
# I1223 09:58:24.402991 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.06645182,
#  'Loss/localization_loss': 0.018248761,
#  'Loss/regularization_loss': 0.14144424,
#  'Loss/total_loss': 0.22614482,
#  'learning_rate': 0.024692658}
# INFO:tensorflow:Step 3600 per-step time 0.112s
# I1223 09:58:35.584021 140143723599744 model_lib_v2.py:705] Step 3600 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.062014937,
#  'Loss/localization_loss': 0.03659825,
#  'Loss/regularization_loss': 0.14119692,
#  'Loss/total_loss': 0.23981011,
#  'learning_rate': 0.021840377}
# I1223 09:58:35.584310 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.062014937,
#  'Loss/localization_loss': 0.03659825,
#  'Loss/regularization_loss': 0.14119692,
#  'Loss/total_loss': 0.23981011,
#  'learning_rate': 0.021840377}
# INFO:tensorflow:Step 3700 per-step time 0.112s
# I1223 09:58:46.812100 140143723599744 model_lib_v2.py:705] Step 3700 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.059656918,
#  'Loss/localization_loss': 0.021624159,
#  'Loss/regularization_loss': 0.14097682,
#  'Loss/total_loss': 0.2222579,
#  'learning_rate': 0.019100051}
# I1223 09:58:46.812390 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.059656918,
#  'Loss/localization_loss': 0.021624159,
#  'Loss/regularization_loss': 0.14097682,
#  'Loss/total_loss': 0.2222579,
#  'learning_rate': 0.019100051}
# INFO:tensorflow:Step 3800 per-step time 0.112s
# I1223 09:58:58.020628 140143723599744 model_lib_v2.py:705] Step 3800 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.075794704,
#  'Loss/localization_loss': 0.049334463,
#  'Loss/regularization_loss': 0.14078265,
#  'Loss/total_loss': 0.26591182,
#  'learning_rate': 0.016488582}
# I1223 09:58:58.020955 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.075794704,
#  'Loss/localization_loss': 0.049334463,
#  'Loss/regularization_loss': 0.14078265,
#  'Loss/total_loss': 0.26591182,
#  'learning_rate': 0.016488582}
# INFO:tensorflow:Step 3900 per-step time 0.114s
# I1223 09:59:09.391216 140143723599744 model_lib_v2.py:705] Step 3900 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.065529436,
#  'Loss/localization_loss': 0.020442583,
#  'Loss/regularization_loss': 0.14061546,
#  'Loss/total_loss': 0.22658747,
#  'learning_rate': 0.014022071}
# I1223 09:59:09.391511 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.065529436,
#  'Loss/localization_loss': 0.020442583,
#  'Loss/regularization_loss': 0.14061546,
#  'Loss/total_loss': 0.22658747,
#  'learning_rate': 0.014022071}
# INFO:tensorflow:Step 4000 per-step time 0.113s
# I1223 09:59:20.698208 140143723599744 model_lib_v2.py:705] Step 4000 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.084986664,
#  'Loss/localization_loss': 0.0476693,
#  'Loss/regularization_loss': 0.14047372,
#  'Loss/total_loss': 0.2731297,
#  'learning_rate': 0.011715729}
# I1223 09:59:20.698509 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.084986664,
#  'Loss/localization_loss': 0.0476693,
#  'Loss/regularization_loss': 0.14047372,
#  'Loss/total_loss': 0.2731297,
#  'learning_rate': 0.011715729}
# INFO:tensorflow:Step 4100 per-step time 0.128s
# I1223 09:59:33.454702 140143723599744 model_lib_v2.py:705] Step 4100 per-step time 0.128s
# INFO:tensorflow:{'Loss/classification_loss': 0.047536414,
#  'Loss/localization_loss': 0.01606317,
#  'Loss/regularization_loss': 0.14035472,
#  'Loss/total_loss': 0.20395431,
#  'learning_rate': 0.009583759}
# I1223 09:59:33.455015 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.047536414,
#  'Loss/localization_loss': 0.01606317,
#  'Loss/regularization_loss': 0.14035472,
#  'Loss/total_loss': 0.20395431,
#  'learning_rate': 0.009583759}
# INFO:tensorflow:Step 4200 per-step time 0.113s
# I1223 09:59:44.760405 140143723599744 model_lib_v2.py:705] Step 4200 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.049695294,
#  'Loss/localization_loss': 0.010229201,
#  'Loss/regularization_loss': 0.14025861,
#  'Loss/total_loss': 0.20018311,
#  'learning_rate': 0.0076393173}
# I1223 09:59:44.760737 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.049695294,
#  'Loss/localization_loss': 0.010229201,
#  'Loss/regularization_loss': 0.14025861,
#  'Loss/total_loss': 0.20018311,
#  'learning_rate': 0.0076393173}
# INFO:tensorflow:Step 4300 per-step time 0.113s
# I1223 09:59:56.043709 140143723599744 model_lib_v2.py:705] Step 4300 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.0824975,
#  'Loss/localization_loss': 0.031053996,
#  'Loss/regularization_loss': 0.14018166,
#  'Loss/total_loss': 0.25373316,
#  'learning_rate': 0.0058943913}
# I1223 09:59:56.044018 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.0824975,
#  'Loss/localization_loss': 0.031053996,
#  'Loss/regularization_loss': 0.14018166,
#  'Loss/total_loss': 0.25373316,
#  'learning_rate': 0.0058943913}
# INFO:tensorflow:Step 4400 per-step time 0.112s
# I1223 10:00:07.246716 140143723599744 model_lib_v2.py:705] Step 4400 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.055572793,
#  'Loss/localization_loss': 0.020652035,
#  'Loss/regularization_loss': 0.14012317,
#  'Loss/total_loss': 0.21634799,
#  'learning_rate': 0.004359741}
# I1223 10:00:07.247026 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.055572793,
#  'Loss/localization_loss': 0.020652035,
#  'Loss/regularization_loss': 0.14012317,
#  'Loss/total_loss': 0.21634799,
#  'learning_rate': 0.004359741}
# INFO:tensorflow:Step 4500 per-step time 0.113s
# I1223 10:00:18.585467 140143723599744 model_lib_v2.py:705] Step 4500 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.04177145,
#  'Loss/localization_loss': 0.01197961,
#  'Loss/regularization_loss': 0.14008066,
#  'Loss/total_loss': 0.19383171,
#  'learning_rate': 0.0030448197}
# I1223 10:00:18.585781 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.04177145,
#  'Loss/localization_loss': 0.01197961,
#  'Loss/regularization_loss': 0.14008066,
#  'Loss/total_loss': 0.19383171,
#  'learning_rate': 0.0030448197}
# INFO:tensorflow:Step 4600 per-step time 0.112s
# I1223 10:00:29.800905 140143723599744 model_lib_v2.py:705] Step 4600 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.03888757,
#  'Loss/localization_loss': 0.016647853,
#  'Loss/regularization_loss': 0.14005166,
#  'Loss/total_loss': 0.19558708,
#  'learning_rate': 0.0019577406}
# I1223 10:00:29.801202 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.03888757,
#  'Loss/localization_loss': 0.016647853,
#  'Loss/regularization_loss': 0.14005166,
#  'Loss/total_loss': 0.19558708,
#  'learning_rate': 0.0019577406}
# INFO:tensorflow:Step 4700 per-step time 0.112s
# I1223 10:00:41.037854 140143723599744 model_lib_v2.py:705] Step 4700 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.06795862,
#  'Loss/localization_loss': 0.03720472,
#  'Loss/regularization_loss': 0.14003369,
#  'Loss/total_loss': 0.24519703,
#  'learning_rate': 0.0011052012}
# I1223 10:00:41.038197 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.06795862,
#  'Loss/localization_loss': 0.03720472,
#  'Loss/regularization_loss': 0.14003369,
#  'Loss/total_loss': 0.24519703,
#  'learning_rate': 0.0011052012}
# INFO:tensorflow:Step 4800 per-step time 0.112s
# I1223 10:00:52.240248 140143723599744 model_lib_v2.py:705] Step 4800 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.10060277,
#  'Loss/localization_loss': 0.09597232,
#  'Loss/regularization_loss': 0.1400242,
#  'Loss/total_loss': 0.3365993,
#  'learning_rate': 0.0004924655}
# I1223 10:00:52.240542 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.10060277,
#  'Loss/localization_loss': 0.09597232,
#  'Loss/regularization_loss': 0.1400242,
#  'Loss/total_loss': 0.3365993,
#  'learning_rate': 0.0004924655}
# INFO:tensorflow:Step 4900 per-step time 0.133s
# I1223 10:01:05.584801 140143723599744 model_lib_v2.py:705] Step 4900 per-step time 0.133s
# INFO:tensorflow:{'Loss/classification_loss': 0.063762285,
#  'Loss/localization_loss': 0.017479187,
#  'Loss/regularization_loss': 0.14002052,
#  'Loss/total_loss': 0.221262,
#  'learning_rate': 0.00012330532}
# I1223 10:01:05.585890 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.063762285,
#  'Loss/localization_loss': 0.017479187,
#  'Loss/regularization_loss': 0.14002052,
#  'Loss/total_loss': 0.221262,
#  'learning_rate': 0.00012330532}
# INFO:tensorflow:Step 5000 per-step time 0.115s
# I1223 10:01:17.077561 140143723599744 model_lib_v2.py:705] Step 5000 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.08335045,
#  'Loss/localization_loss': 0.039339375,
#  'Loss/regularization_loss': 0.14001994,
#  'Loss/total_loss': 0.26270977,
#  'learning_rate': 0.0}
# I1223 10:01:17.077852 140143723599744 model_lib_v2.py:708] {'Loss/classification_loss': 0.08335045,
#  'Loss/localization_loss': 0.039339375,
#  'Loss/regularization_loss': 0.14001994,
#  'Loss/total_loss': 0.26270977,
#  'learning_rate': 0.0}

# %%
pwd
# Out:
# '/content/training_demo'

# %%
# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path /content/training_demo/models/my_ssd_mobilenet_v2_fpnlite/pipeline.config --trained_checkpoint_dir /content/training_demo/models/my_ssd_mobilenet_v2_fpnlite --output_directory /content/training_demo/exported_models/my_model
# Out:
# 2022-12-23 10:08:41.483353: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-23 10:08:41.483474: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2022-12-23 10:08:41.483494: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-12-23 10:08:45.134721: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W1223 10:08:45.211073 139922055325568 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W1223 10:08:45.275782 139922055325568 deprecation.py:623] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f41424e8760>, because it is not built.
# W1223 10:09:02.896166 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f41424e8760>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f412a1a87c0>, because it is not built.
# W1223 10:09:03.125782 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f412a1a87c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a13e520>, because it is not built.
# W1223 10:09:03.126000 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a13e520>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a13e910>, because it is not built.
# W1223 10:09:03.126111 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a13e910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f412a183d90>, because it is not built.
# W1223 10:09:03.126204 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f412a183d90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a183a90>, because it is not built.
# W1223 10:09:03.126284 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a183a90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a183d30>, because it is not built.
# W1223 10:09:03.126361 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a183d30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f412a4a1cd0>, because it is not built.
# W1223 10:09:03.126435 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f412a4a1cd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f41421b5be0>, because it is not built.
# W1223 10:09:03.126513 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f41421b5be0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a384ee0>, because it is not built.
# W1223 10:09:03.126589 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a384ee0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f412a44ff10>, because it is not built.
# W1223 10:09:03.126673 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f412a44ff10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f41422c6f40>, because it is not built.
# W1223 10:09:03.126749 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f41422c6f40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a12a2e0>, because it is not built.
# W1223 10:09:03.126823 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a12a2e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a12aca0>, because it is not built.
# W1223 10:09:03.126896 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a12aca0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a122a60>, because it is not built.
# W1223 10:09:03.126975 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a122a60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a1722e0>, because it is not built.
# W1223 10:09:03.127048 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a1722e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1721c0>, because it is not built.
# W1223 10:09:03.127122 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1721c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a172730>, because it is not built.
# W1223 10:09:03.127194 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a172730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1726a0>, because it is not built.
# W1223 10:09:03.127267 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1726a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a172d00>, because it is not built.
# W1223 10:09:03.127339 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a172d00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a172af0>, because it is not built.
# W1223 10:09:03.127412 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a172af0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a3caf10>, because it is not built.
# W1223 10:09:03.127485 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a3caf10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a128190>, because it is not built.
# W1223 10:09:03.127558 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a128190>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a128880>, because it is not built.
# W1223 10:09:03.127631 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a128880>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1288e0>, because it is not built.
# W1223 10:09:03.127718 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1288e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a128fa0>, because it is not built.
# W1223 10:09:03.127798 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a128fa0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a128700>, because it is not built.
# W1223 10:09:03.127871 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a128700>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a2c7be0>, because it is not built.
# W1223 10:09:03.127951 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a2c7be0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a2c7130>, because it is not built.
# W1223 10:09:03.128033 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a2c7130>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f414204aa60>, because it is not built.
# W1223 10:09:03.128107 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f414204aa60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a12d580>, because it is not built.
# W1223 10:09:03.128180 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a12d580>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a12d910>, because it is not built.
# W1223 10:09:03.128254 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a12d910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1b7dc0>, because it is not built.
# W1223 10:09:03.128330 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1b7dc0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a1b7400>, because it is not built.
# W1223 10:09:03.128402 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a1b7400>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1b7670>, because it is not built.
# W1223 10:09:03.128474 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1b7670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a1b7b20>, because it is not built.
# W1223 10:09:03.128547 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a1b7b20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1b7be0>, because it is not built.
# W1223 10:09:03.128623 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1b7be0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a096a90>, because it is not built.
# W1223 10:09:03.128707 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a096a90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a182760>, because it is not built.
# W1223 10:09:03.128781 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a182760>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a182ee0>, because it is not built.
# W1223 10:09:03.128853 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a182ee0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1827c0>, because it is not built.
# W1223 10:09:03.128926 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1827c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a1a7160>, because it is not built.
# W1223 10:09:03.129004 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a1a7160>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1a7220>, because it is not built.
# W1223 10:09:03.129076 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1a7220>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a1a7730>, because it is not built.
# W1223 10:09:03.135593 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f412a1a7730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1a77f0>, because it is not built.
# W1223 10:09:03.135818 139922055325568 save_impl.py:66] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f412a1a77f0>, because it is not built.
# W1223 10:09:18.958123 139922055325568 save.py:271] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/training_demo/exported_models/my_model/saved_model/assets
# I1223 10:09:24.153561 139922055325568 builder_impl.py:797] Assets written to: /content/training_demo/exported_models/my_model/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to /content/training_demo/exported_models/my_model/pipeline.config
# I1223 10:09:25.130916 139922055325568 config_util.py:253] Writing pipeline config file to /content/training_demo/exported_models/my_model/pipeline.config

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] ='2'
import pathlib
import tensorflow as tf
import cv2
import argparse
from google.colab.patches import cv2_imshow

gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)

IMAGE_PATHS = '/content/training_demo/images/test/hard_hat_workers4823.png'

PATH_TO_MODEL_DIR = '/content/training_demo/exported_models/my_model'

PATH_TO_LABELS = '/content/training_demo/annotations/label_map.pbtxt'

MIN_CONF_THRESH = float(0.60)

import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
     
PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "/saved_model"

print('Loading model....' , end='')
start_time = time.time()

detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

end_time = time.time()
elapsed_time = end_time - start_time

print('Done! Took {} seconds'.format(elapsed_time))

category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS,use_display_name=True)

import numpy as np
from PIL import Image
import matplotlib as plt
import warnings
warnings.filterwarnings('ignore')

def load_image_into_numpy_array(path):
  return np.array(Image.open(path))

print('Running inference for {}...'.format(IMAGE_PATHS), end='')

image = cv2.imread(IMAGE_PATH)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_expanded = np.expand_dims(image_rgb, axis=0)

input_tensor = tf.convert_to_tensor(image)

input_tensor = input_tensor[tf.newaxis, ...]

detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
               for key, value in detections.items()}
detections['num_detections'] = num_detections

detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

image_with_detections = image.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
    image_with_detections,
    detections['detection_boxes'],
    detections['detection_classes'],
    detections['detection_scores'],
    category_index,
    use_normalized_coordinates=True,
    max_boxes_to_draw=200,
    min_score_thresh=0.5,
    agnostic_mode=False)

print('Done')
cv2_imshow(image_with_detections)
# Out:
# Loading model....Done! Took 10.614658117294312 seconds
# Running inference for /content/training_demo/images/test/hard_hat_workers4823.png...Done
# <PIL.Image.Image image mode=RGB size=416x415 at 0x7F92011FA910>
